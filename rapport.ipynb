# %% [markdown]
# ## RAPPORT DU PROJET N1
#
# ### ETAPES SUIVIES

# %% [markdown]
# ##### ETAPE 1: TELCHARGER LE DATASET SUR KAGGLE on a telecharger le dataset "sensor_dataset.csv"

# %% [markdown]
# ##### ETAPE 2: OUVRIR SON VSCODE ET INSTALLER LES LIBRAIRIES (BIBLIOTHEQUES) SUIVANTES SI C'EST PAS DEJA LE CAS:  Pandas,Seaborn,Matplotlib

# %% [markdown]
# ##### Etape 3 : NETTOYAGE DU DATA SET
# ###### ici on verifie les valeurs manquantes , et on les remplaces , soit par la moyenne ou les valeurs les plus presentes(mode). Dans notre cas on a remplace les donnees manquqntes par la moyenne. Cela a ete le cas pour les colonnes : temperatures, humidity et pressure

# %% [markdown]
# ##### ETAPE 4: CUSTUM FONCTIONS
# Ici il etait question d'ecrire les fonctions statistiques qui seront appliques a notre dataset. Pas question d'utiliser les fonctions natives de python telque meand(),max(),min() ou describe . Mais ici il a ete question d'ecricre nos propres fonctions statistiques. On en a donc creé 07 qui sont :
# moyenne(qui renvoi la moyenne d'une colonne),minimum(qui renvoi l'element le plus petit d'une colonne),maximum(qui renvoi l'element le plus grand d'une colonne),variance(qui montre si les valeurs d'une colonne sont proche ou eloignes de la moyenne),mediane(qui renvoie lorsque le tableau est trie la valeur qui est au centre du tableau),modt(cette fonction permet de montrer l'element le plus frequent dans une colonne) et nbe_ligne(cette fonction retourne le nombre de lignes d'une cologne)

# %% [markdown]
# ##### ETAPE 5: STOCKAGE DES DONNES STATISTIQUES DANS UN DICTIONNAIRE ET AFFICHAGE
# A ce niveau vu qu'on a apllique les fonctions statistiques sur 3 colonnes , on a donc fait une boucle pour parcourir les noms de ces colonnes (on a mis ces noms dans un tableau ). on a cree un dictionnaire statistiques qui est vide au debut, Lors du parcours , a chaque tour de la boucle pour , i prends la valeur de la colone par exemple ("temperature") et a statistiques[i] = un nouveau dictionnaire qui comprends donc cette fois en cle le nom d'une fonction , et en valeur l'appel de la fonction avec comme parametre (i). ainsi automatiquement , le dictionnaire va se remplir.

# %% [markdown]
# ##### ETAPE 6: VISUALISATION DES COURBES
# A c niveau il etait question d'afficher les differentes courbes par element de la colonne ; Nous avons donc decide de tracer les courbes suivantes : Histogramme (qui represente la distribution des differentes valeurs avec leurs frequences) en utilisant plt.hist() de matplotplit.pyplot, courbe temporelle(qui montre l'evolution d'une variable du dataset en fonction du temps)en utilisant .hist() de matplotplit.pyplot,la boite a moustaches ( qui represente la dispersion des donnes autours de la moyenne,montrant le min,le max,et les differents quartiles)en utilisant .boxplot  de seaborn et le headmap qui reppresente une correlation entre les differentes colonnes du dataset en utilisant heatmap de seaborn.
